# %%
import numpy as np
import pandas as pd

# %%
data = {'name' : ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
         'age' : [42, 52, 36, 24, 73],
         'preTestScore' : [4, 24, 31, 2, 3],
         'postTestScore' : [ 25, 94, 57, 62, 70]}
df = pd.DataFrame(data, columns = ['name', 'age', 'preTestScore', 'postTestScore'])
df
# Out:
#     name  age  preTestScore  postTestScore
# 0  Jason   42             4             25
# 1  Molly   52            24             94
# 2   Tina   36            31             57
# 3   Jake   24             2             62
# 4    Amy   73             3             70

# %%
print(df['age'].sum())
print(df['preTestScore'].mean())
print(df['preTestScore'].describe()) # 데이터 분포를 알고 싶을때
print(df['preTestScore'].cumsum())

print(df['preTestScore'].var())
print(df['preTestScore'].std())
print(df['preTestScore'].skew()) #데이터가 한쪽으로 너무 쏠려있을때, 정규분포로 작업하기 위한 함수, skew로 데이터이 치우침을 파악
# Out:
# 227
# 12.8
# count     5.000000
# mean     12.800000
# std      13.663821
# min       2.000000
# 25%       3.000000
# 50%       4.000000
# 75%      24.000000
# max      31.000000
# Name: preTestScore, dtype: float64
# 0     4
# 1    28
# 2    59
# 3    61
# 4    64
# Name: preTestScore, dtype: int64
# 186.7
# 13.663820841916802
# 0.7433452457326751

# %%
df.corr() #데이터의 상관계수를 보는거!!, 직선의 관계가 높다!=>하나의 데이터만 사용해도 됨.
# Out:
#                     age  preTestScore  postTestScore
# age            1.000000     -0.105651       0.328852
# preTestScore  -0.105651      1.000000       0.378039
# postTestScore  0.328852      0.378039       1.000000

# %%
len(stock_price_DF_withIndex["저가"].unique()) ==len(stock_price_DF_withIndex)# 여러개 값 중복으로 출력하지 않음
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-727530898992> in <module>
# ----> 1 len(stock_price_DF_withIndex["저가"].unique()) ==len(stock_price_DF_withIndex)# 여러개 값 중복으로 출력하지 않음
#
# NameError: name 'stock_price_DF_withIndex' is not defined

# %%
len(stock_price_DF_withIndex) #가로줄 리턴해줌 = .shape이랑 같은 기능

# %%
from numpy import nan as NA

data = pd.DataFrame([[1,6.5,3],[1,NA,NA],[NA,NA,NA],[NA,6.5,3]])
cleanded = data.dropna()
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna() #가로기준 : 가로축으로 na 하나라도 있으면 다 지워버려 >>완벽한 데이터를 만들때 활용
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
data.dropna(axis=1) #세로기준, 거의 쓸일 없음
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df = pd.DataFrame(np.random.randn(7,3))
df.iloc[:4,1] = NA
df.iloc[:2,2] = NA
df
# Out:
#           0         1         2
# 0  0.413301       NaN       NaN
# 1 -0.591001       NaN       NaN
# 2  0.693506       NaN  0.332360
# 3 -0.955594       NaN  0.657800
# 4  0.048402  0.792544 -0.449428
# 5 -0.130801 -0.934692  0.471126
# 6  1.333161 -1.256437  0.328653

# %%
df.dropna()
# Out:
#           0         1         2
# 4  0.048402  0.792544 -0.449428
# 5 -0.130801 -0.934692  0.471126
# 6  1.333161 -1.256437  0.328653

# %%
df.dropna(axis=1)
# Out:
#           0
# 0  0.413301
# 1 -0.591001
# 2  0.693506
# 3 -0.955594
# 4  0.048402
# 5 -0.130801
# 6  1.333161

# %%
df.dropna(thresh=1) #가로줄 기준으로, 정상인 값이 하나이상인 것은 살려주세요
# Out:
#           0         1         2
# 0  0.413301       NaN       NaN
# 1 -0.591001       NaN       NaN
# 2  0.693506       NaN  0.332360
# 3 -0.955594       NaN  0.657800
# 4  0.048402  0.792544 -0.449428
# 5 -0.130801 -0.934692  0.471126
# 6  1.333161 -1.256437  0.328653

# %%
df.dropna(thresh=3, axis=1) #가로줄 기준으로, 정상인 값이 둘이상인 것은 살려주세요
# Out:
#           0         1         2
# 0  0.413301       NaN       NaN
# 1 -0.591001       NaN       NaN
# 2  0.693506       NaN  0.332360
# 3 -0.955594       NaN  0.657800
# 4  0.048402  0.792544 -0.449428
# 5 -0.130801 -0.934692  0.471126
# 6  1.333161 -1.256437  0.328653

# %%
df.fillna(1000)
# Out:
#           0            1            2
# 0  0.413301  1000.000000  1000.000000
# 1 -0.591001  1000.000000  1000.000000
# 2  0.693506  1000.000000     0.332360
# 3 -0.955594  1000.000000     0.657800
# 4  0.048402     0.792544    -0.449428
# 5 -0.130801    -0.934692     0.471126
# 6  1.333161    -1.256437     0.328653

# %%
df #원본데이터는 살아있음!!!!

# %%
df.fillna({1:99 , 3:-99}) #칼럼마다 다른 값을 부여할 경우 : dictionary 사용!!
#파이선은 없어도 에러를 안띄우기 때문에 꼭 확인하기!!!
# Out:
#           0          1         2
# 0  0.413301  99.000000       NaN
# 1 -0.591001  99.000000       NaN
# 2  0.693506  99.000000  0.332360
# 3 -0.955594  99.000000  0.657800
# 4  0.048402   0.792544 -0.449428
# 5 -0.130801  -0.934692  0.471126
# 6  1.333161  -1.256437  0.328653

# %%
import os 
import sys
sys.version
# Out:
# '3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]'

# %%
testCSV_path = "sampledata\\01_olive.csv"#상대경로. 

olive_oil = pd.read_csv(testCSV_path, header=None) #더블클릭해서 여는 용도 : readCSV --자동적으로 데이터프레임으로 받아옴 
#header=None >>첫번째 값을 value로 읽어들이는거!! 자동으로 컬럼업데이트 안함 
olive_oil.head(3)
# Out:
#                0       1     2         3            4        5      6   \
# 0             NaN  region  area  palmitic  palmitoleic  stearic  oleic
# 1  1.North-Apulia       1     1      1075           75      226   7823
# 2  2.North-Apulia       1     1      1088           73      224   7709
#
#          7          8          9           10
# 0  linoleic  linolenic  arachidic  eicosenoic
# 1       672         36         60          29
# 2       781         31         61          29

# %%
#names : 미스매칭이 나면, 값을 뒤에서 채워 넣어. 갯수를 맞춰야해 
olive_oil = pd.read_csv(testCSV_path, names=['a', 'b', 'c','d']) 
olive_oil.head(3)

# %%
#skiprows :skip!!
olive_oil = pd.read_csv(testCSV_path, skiprows=1) 
olive_oil.head(3)

# %%
olive_oil = pd.read_csv(testCSV_path) 
olive_oil.head(3)
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29

# %%
olive_oil.rename(columns ={olive_oil.columns[0]:"id_area"}, inplace=True) #컬럼을 바꿀꺼다. 무엇을 무엇으로 =>복수니까 딕셔너리 
olive_oil.head(3)
# Out:
#           id_area  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29

# %%
type(olive_oil["id_area"]) #series

# %%
len(olive_oil["id_area"].unique()) #모든 값이 다 unique 하니까 index로 활용가능하다!!!

# %%
len(olive_oil)

# %%
olive_oil.shape[0]

# %%
olive_oil['id_area'][0]

# %%
str(int('1.North-Apulia'.split('.')[0])-1)+"_"+'1.North-Apulia'.split('.')[1]

# %%
olive_oil['id_area'] = olive_oil['id_area'].apply(lambda x: str(int(x.split('.')[0])-1)+"_"+x.split('.')[1])
olive_oil.head(3)
# Out:
#           id_area  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  0_North-Apulia       1     1      1075           75      226   7823
# 1  1_North-Apulia       1     1      1088           73      224   7709
# 2  2_North-Apulia       1     1       911           54      246   8113
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29

# %%
olive_oil['palmitoleic'] = olive_oil['palmitoleic'].apply(lambda x : x*10000 )
olive_oil.head(3)
# Out:
#           id_area  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  0_North-Apulia       1     1      1075         0.75      226   7823
# 1  1_North-Apulia       1     1      1088         0.73      224   7709
# 2  2_North-Apulia       1     1       911         0.54      246   8113
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29

# %%
olive_oil.to_csv('olive2.csv')

# %%
comma_path = "sampledata\\02_surveys.csv"

data_comma = pd.read_csv(comma_path, sep=",")
data_comma
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
at_path = "sampledata\\03_surveys_withAt.csv"

#sep : 구별자
data_at = pd.read_csv(at_path, sep ="@")
data_at
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
import sys
import os
import glob

# %%
glob.glob(many_file_path)[0]
# Out:
# 'sampledata\\06_manyfile\\1763.csv'

# %%
os.path.basename(glob.glob(many_file_path)[0]).split('.')[0]
# Out:
# '1763'

# %%
#확장자가 같은 파일을 한번에 가지고오고, 이름을 data_xxxx로 바꾸는 과정 
#*.csv
many_file_path ="sampledata\\06_manyfile\\*.csv"

file_path_list = glob.glob(many_file_path) #glob : 경로 가지고 옴

for i in range(0, len(file_path_list)) :
    temp = os.path.basename(file_path_list[i]) #basename : 기본적인 이름만 가지고옴 
    temp = os.path.splitext(temp)[0] #splitext()
    
    #data_1763 만들기
    vars()["data_" + str(temp)] = pd.read_csv(file_path_list[i]) #vars : 문자열을 변수명으로

# %%
data_1763.head()
# Out:
#    ITE00100554  17630101  TMAX  -36  Unnamed: 4 Unnamed: 5  E  Unnamed: 7
# 0  ITE00100554  17630101  TMIN  -50         NaN        NaN  E         NaN
# 1  ITE00100554  17630102  TMAX  -26         NaN        NaN  E         NaN
# 2  ITE00100554  17630102  TMIN  -40         NaN        NaN  E         NaN
# 3  ITE00100554  17630103  TMAX   -9         NaN        NaN  E         NaN
# 4  ITE00100554  17630103  TMIN  -29         NaN        NaN  E         NaN

# %%
#여러 데이터 합치는 중>>
many_file_path ="sampledata\\06_manyfile\\*.csv"
file_path_list = glob.glob(many_file_path) 

data_tot = pd.DataFrame()

for i in range(0, len(file_path_list)) :
    data_tot = data_tot.append(pd.read_csv(file_path_list[i], header=None), ignore_index=True) #ignore_index : index 재정렬

# %%
data_tot.shape
# Out:
# (7306, 8)

# %%
#엑셀파일 읽어들이기 : 엑셀은 시트를 중심으로 움직인다.

excel_path = "sampledata\\07_surveys_excelformat.xls"
excel_data = pd.read_excel(excel_path, sheet_name="Sheet1") #시트이름을 반드시 지정해주어야 한다. 
excel_data.head(3)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN

# %%
excel_data=excel_data.fillna(0)
excel_data.head(3)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     0.0
# 1     0.0
# 2     0.0

# %%
excel_out_path1 = "test_excel_old.xls"
excel_out_path2 = "test_excel_new.xlsx"
excel_data.to_excel(excel_out_path1)
excel_data.to_excel(excel_out_path2)

# %%
#파일 데이터 >> 메모리 용량 : 쪼개서 처리해야 한다.
big_file_path = 'sampledata\\star0000-1.csv'

chunker = pd.read_csv(big_file_path, chunksize=1000)
tot = pd.concat([x for x in chunker], ignore_index=True)
tot.shape
# Out:
# (2173761, 12)

# %%
pd.read_csv(big_file_path).head()
# Out:
#    266   909   159625   159627   2635   20000827.0117590018   1239029   1341  \
# 0  317  1243   159625   159627   2636          2.000083e+07   1239029   1470
# 1  281  1285   159625   159627   2637          2.000083e+07   1239029   1663
# 2  204  1198   159625   159627   2638          2.000083e+07   1239029   1806
# 3  288   988   159625   159627   2639          2.000083e+07   1239029   1409
# 4  251  1232   159625   159627   2640          2.000083e+07   1239029    930
#
#     -26.399744   1228   0.56000537   48
# 0   -29.075420   1415     0.464418   53
# 1    -6.753542   1533     0.535974    8
# 2    11.985353   1123     0.668971   32
# 3   -12.928666   1314     0.584983   39
# 4    26.815605   1153     0.532364   54

# %%
stock_Price_DF_withIndex=pd.DataFrame([10000, 10300, 9900, 10500, 11000],
                                     index = ["2016-03-01", "2016-03-02", "2016-03-03", "2016-03-04", "2016-03-5"])
stock_Price_DF_withIndex.rename(columns={0:"시가"}, inplace=True)
stock_Price_DF_withIndex["종가"] = [11000, 12000, 10000, 13000, 12000]
stock_Price_DF_withIndex["고가"] = [13000, 15000, 15000, 18000, 17000]
stock_Price_DF_withIndex["저가"] = [3000, 50000, 5000, 8000, 7000]

stock_Price_DF_withIndex
# Out:
#                시가     종가     고가     저가
# 2016-03-01  10000  11000  13000   3000
# 2016-03-02  10300  12000  15000  50000
# 2016-03-03   9900  10000  15000   5000
# 2016-03-04  10500  13000  18000   8000
# 2016-03-5   11000  12000  17000   7000

# %%
stock_Price_DF_withIndex.loc["2016-03-01", 0:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-189-f00ffce73b38> in <module>
# ----> 1 stock_Price_DF_withIndex.loc["2016-03-01", 0:1]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1269     def _getitem_tuple(self, tup: Tuple):
#    1270         try:
# -> 1271             return self._getitem_lowerdim(tup)
#    1272         except IndexingError:
#    1273             pass
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
# ...
